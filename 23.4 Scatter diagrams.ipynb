# %%
import matplotlib.pyplot as scatter

# %%
x = [1,2,3,4,5]
y = [2,4,3,7,9]

# %%
scatter.scatter(x,y,
                label = 'stars',
                marker = '*',
                color = 'y'
               ,s = 30)
