# %%
import matplotlib.pyplot as pc

# %%
activities = ['Tech','Music','Efootball','Guitar']
portions = [2,3,5,1]
colours = ['blue','green','magenta','red']
pie_chart = pc.pie(portions, labels = activities , colors= colours, startangle = 90, shadow = True)
